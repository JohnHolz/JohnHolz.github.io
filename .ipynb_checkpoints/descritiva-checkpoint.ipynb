# %%
from selenium import webdriver
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
import time 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.DataFrame(pd.read_html(site)[1])
new_header = df.iloc[0] 
df = df[1:-2]
df.columns = new_header
df.index = df.iloc[:,0]
df = df.drop(['Ano/Estados'],axis=1)
df = df.apply(pd.to_numeric)

# %%
_ = plt.title('Acumulado Desmatamento',fontsize=18)
_ = plt.pie(df.iloc[:,:-1].sum(),labels=df.iloc[:,:-1].columns)

# %%
_ = plt.title('Amazônia Legal - 1988',fontsize=18)
_ = plt.pie(df.iloc[0,:-1],labels=df.iloc[:,:-1].columns)

# %%
_ = df.plot(marker='o')
_ = plt.legend(title="")
_ = plt.title('Amazônia Legal - Desmatamento por estado e Ano',fontsize=18)

# %%
_ = df.cumsum().plot(marker='')
_ = plt.legend(title="")
_ = plt.title('Acumulado por estado e Ano - desde 1988',fontsize=18)

# %%
import geopandas as gpd, geobr as gbr

# %%
estados = gbr.read_state()
to_merge = pd.DataFrame(df.sum())
to_merge.columns = ['desmatamento']
to_merge.index.name = 'estado'

# %%
estados = estados.join(to_merge,on='abbrev_state')
estados = estados.dropna()

# %%
estados
# Out:
#     code_state abbrev_state   name_state  code_region   name_region  \
# 0         11.0           RO     Rondônia          1.0         Norte
# 1         12.0           AC         Acre          1.0         Norte
# 2         13.0           AM     Amazonas          1.0         Norte
# 3         14.0           RR      Roraima          1.0         Norte
# 4         15.0           PA         Pará          1.0         Norte
# 5         16.0           AP        Amapá          1.0         Norte
# 6         17.0           TO    Tocantins          1.0         Norte
# 7         21.0           MA     Maranhão          2.0      Nordeste
# 24        51.0           MT  Mato Grosso          5.0  Centro Oeste
#
#                                              geometry  desmatamento
# 0   MULTIPOLYGON (((-63.32721 -7.97672, -62.86662 ...       64623.0
# 1   MULTIPOLYGON (((-73.18253 -7.33550, -72.58477 ...       16668.0
# 2   MULTIPOLYGON (((-67.32609 2.02971, -67.31682 2...       30790.0
# 3   MULTIPOLYGON (((-60.20051 5.26434, -60.19273 5...        8909.0
# 4   MULTIPOLYGON (((-54.95431 2.58369, -54.93542 2...      162612.0
# 5   MULTIPOLYGON (((-51.17970 4.00008, -51.17739 3...        1656.0
# 6   MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...        8763.0
# 7   MULTIPOLYGON (((-45.84073 -1.04548, -45.84099 ...       26103.0
# 24  MULTIPOLYGON (((-54.89485 -17.62150, -54.89704...      150151.0

# %%
f, ax = plt.subplots()
_ = f.set_size_inches(16, 16)
_ = estados.plot(ax = ax,
             column= 'desmatamento',
             cmap="Greens",
             edgecolor="black",
             linewidth=0.25)
